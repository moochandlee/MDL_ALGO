# %%
# !pip install simfin

# %%
import simfin as sf
import pandas as pd
import os 
from dotenv import load_dotenv

# %%
print(os.path.expanduser("~"))

load_dotenv()

api_key = os.getenv("sf_key")

sf.set_api_key(api_key)

# Setup a place (local directory) to store the data 
sf.set_data_dir('~/Code/SimFin')
# Out:
# /Users/mdl
